# %%
import numpy as np # Pour faire des maths et gérer des matrices
import pandas as pd # Pour manipuler les données (lire des CSV, créer des tableaux)
import os # Pour interagir avec le système de fichiers de l'ordinateur
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import gc
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./metadata.csv')
df.head()
# Out:
#                         Image                        Mask
# 0    water_body_1000_blur.jpg    water_body_1000_blur.jpg
# 1  water_body_1000_bright.jpg  water_body_1000_bright.jpg
# 2    water_body_1000_flip.jpg    water_body_1000_flip.jpg
# 3    water_body_1000_orig.jpg    water_body_1000_orig.jpg
# 4   water_body_1000_rot40.jpg   water_body_1000_rot40.jpg

# %%
df.columns
# Out:
# Index(['Image', 'Mask'], dtype='object')

# %%
image_dir = './Images'
mask_dir = './Masks'

# On choisit un fichier spécifique (ID) qui existe dans les deux dossiers
base_filename = 'water_body_186_orig'

#  On construit les chemins d'accès.
# L'image est souvent en JPG (photo) et le masque en PNG (pour garder les valeurs exactes des pixels)
image_path = os.path.join(image_dir, base_filename + '.jpg')
mask_path = os.path.join(mask_dir, base_filename + '.jpg')

# C'est ici qu'on transforme les fichiers en tableaux de nombres (matrices) pour que le modèle puisse les lire.
# L'image est chargée normalement (en couleur BGR par défaut avec OpenCV)
img = cv2.imread(image_path)
# Le masque est chargé IMPÉRATIVEMENT en niveaux de gris (Grayscale)
# Car chaque pixel représente une classe (ex: 0=fond, 1=chat), pas une couleur visuelle.
mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

# %%
# Verification Est-ce que l'image existe ?
if img is not None:
    
    #   mettre les 2 images côte à côte
    plt.figure(figsize=(10, 4))
    
    # --- IMAGE DE GAUCHE (La Photo) ---
    plt.subplot(1, 2, 1) # 1 ligne, 2 colonnes, position 1
    
    # Conversion CRUCIALE : OpenCV est en BGR, on doit convertir en RGB pour l'affichage correct
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title("Image Originale")
    plt.axis('off') # On cache les axes chiffrés pour faire plus propre
    
    # --- IMAGE DE DROITE (Le Masque) ---
    plt.subplot(1, 2, 2) # 1 ligne, 2 colonnes, position 2
    
    # On affiche le masque en niveaux de gris (noir et blanc) pour bien voir les classes
    plt.imshow(mask, cmap='gray')
    plt.title("Masque de Segmentation")
    plt.axis('off')
    
    #  On affiche le résultat final à l'écran
    plt.show()

else:
    # Si le chargement a échoué, on prévient l'utilisateur
    print("Erreur : L'image est vide. Vérifie ton chemin d'accès (path).")

# %%
IMG_PATH = './images'
MASK_PATH = './masks'
IMG_SIZE = 128 # Taille cible pour l'entrée du réseau (plus c'est petit, plus c'est rapide)

# On liste tout ce qu'il y a dans les dossiers
image_files = sorted(os.listdir(IMG_PATH))
mask_files = sorted(os.listdir(MASK_PATH))

# On ne garde que le nom sans l'extension 
image_basenames = set([f.split('.')[0] for f in image_files])
mask_basenames = set([f.split('.')[0] for f in mask_files])

# L'opération '&' (intersection) ne garde que les noms présents dans les DEUX dossiers
# Cela évite les erreurs si une image n'a pas de masque correspondant
common_basenames = sorted(list(image_basenames & mask_basenames))

# ---  CHARGEMENT ET PRETRAITEMENT ---
X, Y = [], [] # Listes vides pour stocker les données finales

for name in common_basenames:
    # Chargement
    img = cv2.imread(f"{IMG_PATH}/{name}.jpg")
    mask = cv2.imread(f"{MASK_PATH}/{name}.jpg", 0) # 0 force le mode Noir & Blanc (1 canal)

    # Sécurité : Si le fichier est corrompu ou illisible, on l'ignore
    if img is not None and mask is not None:
        
        # Redimensionnement pour uniformiser la taille
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        mask = cv2.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # Normalisation : On passe de [0, 255] à [0, 1]
        # Cela aide le réseau de neurones à apprendre plus vite (convergence)
        img = img / 255.0
        mask = mask / 255.0

        # Ajout aux listes principales
        X.append(img)
        Y.append(mask)

# %%
# Conversion des Images (X)
# On transforme la liste en un tableau Numpy (Matrix).
# Comme les images sont en couleur, la forme sera automatiquement (N, 128, 128, 3)
X = np.array(X, dtype=np.float32)
# Nettoyage final
gc.collect()

# 2. Conversion et Remodelage des Masques (Y)
# D'abord on convertit en Numpy array.
# Ensuite, on utilise .reshape() pour ajouter la dimension du canal "Channel".
# -1 : "Prends toutes les images disponibles" (Batch size automatique)
# 1  : "Il n'y a qu'un seul canal de couleur" (Niveaux de gris)
# Forme finale : (N, 128, 128, 1)
Y = np.array(Y, dtype=np.float32).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# Nettoyage final
gc.collect()


print(f"Forme de X (Images) : {X.shape}") 
print(f"Forme de Y (Masques) : {Y.shape}")
# Out:
# Forme de X (Images) : (14205, 128, 128, 3)
# Forme de Y (Masques) : (14205, 128, 128, 1)

# %%
# Découpage des données
# X_train, Y_train : Données pour apprendre (Training set)
# X_test, Y_test   : Données pour valider/tester (Validation set)
X_train, X_test, Y_train, Y_test = train_test_split(
    X,              # Les images (features)
    Y,      # Les masques (labels)
    test_size=0.2,  # On garde 20% des images pour le test (donc 80% pour l'entraînement)
    random_state=42 # Assure que le mélange est reproductible (toujours le même découpage)
)

# Petit contrôle pour voir combien d'images on a dans chaque groupe
print(f"Images d'entraînement : {X_train.shape[0]}")
print(f"Images de test : {X_test.shape[0]}")
# Out:
# Images d'entraînement : 11364
# Images de test : 2841

# %%
#  LA MÉTRIQUE "IoU" (Le Juge Impartial)
def iou_metric(y_true, y_pred):
    # Pourquoi cette fonction ?
    # L'accuracy classique (précision) est menteuse en segmentation (surtout s'il y a beaucoup de fond noir).
    # L'IoU mesure vraiment si la forme dessinée se superpose bien à la vraie forme.

    # Si > 0.5 alors c'est un pixel blanc (1), sinon c'est noir (0).
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    
    # Intersection : On compte les pixels où l'IA et la Vérité sont d'accord (Blanc sur Blanc).
    intersection = tf.reduce_sum(y_true * y_pred)
    
    # Union : C'est la surface totale occupée par les deux masques réunis.
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    
    # Le calcul final : Intersection divisée par Union.
    # Le "+ 1e-7" est une sécurité mathématique pour éviter une division par zéro (crash) si l'image est vide.
    return intersection / (union + 1e-7)

#  L'ARCHITECTURE U-NET (Le Cerveau en forme de U)

def build_unet(input_shape=(128, 128, 3)):
    
    # On définit la porte d'entrée du modèle (taille de l'image)
    inputs = Input(input_shape)

    # --- PARTIE 1 : LA DESCENTE (L'Encodeur) ---
    # Le but : Comprendre "QUOI" est sur l'image (contexte).
    # On réduit la taille de l'image petit à petit, mais on augmente le nombre de filtres (caractéristiques).

    # Étage 1 : Haute résolution
    # Conv2D : L'œil de l'IA scanne l'image pour trouver des traits simples.
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = Dropout(0.1)(c1) # On "éteint" 10% des neurones au hasard pour forcer les autres à mieux travailler.
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1) # Zoom arrière : On divise la taille par 2. On garde c1 en mémoire !

    # Étage 2 : Résolution Moyenne
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2) # Zoom arrière encore. On garde c2 en mémoire !

    # Étage 3 : Basse Résolution
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3) # On augmente un peu le Dropout car on a plus de filtres.
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3) # Zoom arrière. On garde c3 en mémoire !

    # --- PARTIE 2 : LE FOND DU GOUFFRE (Bottleneck) ---
    # C'est le point le plus compressé. L'image est toute petite (pixels), mais très riche en infos abstraites.
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)

    # --- PARTIE 3 : LA REMONTÉE (Le Décodeur) ---
    # Le but : Savoir "OÙ" est l'objet et reconstruire le masque précis.
    # C'est ici que la magie du U-Net opère grâce aux "Ponts" (concatenate).

    # Remontée 1
    u5 = UpSampling2D((2, 2))(c4) # Zoom avant : On agrandit l'image.
    # LE PONT (Skip Connection) : On colle l'image floue actuelle (u5) avec l'image nette de l'étape 3 (c3).
    # Cela permet de retrouver les détails perdus lors de la descente.
    u5 = concatenate([u5, c3]) 
    c5 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u5)
    c5 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    # Remontée 2
    u6 = UpSampling2D((2, 2))(c5)
    u6 = concatenate([u6, c2]) # On récupère les détails de l'étage 2
    c6 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    # Remontée 3
    u7 = UpSampling2D((2, 2))(c6)
    u7 = concatenate([u7, c1]) # On récupère les détails de l'étage 1 (très haute définition)
    c7 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    # --- SORTIE ---
    # On veut une seule image finale en noir et blanc (1 canal).
    # 'sigmoid' force chaque pixel à être une probabilité entre 0 (Noir) et 1 (Blanc).
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)

    # On assemble le tout dans un modèle Keras
    model = Model(inputs=[inputs], outputs=[outputs])
    return model


#  COMPILATION DU MODÈLE
# On construit l'architecture
model = build_unet()

# On donne les règles du jeu au modèle :
# - optimizer='adam' : C'est le coach qui ajuste les neurones pour réduire l'erreur.
# - loss='binary_crossentropy' : La méthode pour calculer l'erreur (Pixel Noir vs Pixel Blanc).
# - metrics : On lui demande d'afficher l'Accuracy (classique) ET notre IoU (la vraie note).
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', iou_metric])

# Affiche le résumé technique (nombre de paramètres, forme des couches...)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 128, 128, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 128, 128, 16)      │             448 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128, 128, 16)      │               0 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 128, 128, 16)      │           2,320 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 64, 16)        │               0 │ conv2d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 64, 64, 32)        │           4,640 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 64, 64, 32)        │               0 │ conv2d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 64, 64, 32)        │           9,248 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 32, 32)        │               0 │ conv2d_3[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_4 (Conv2D)             │ (None, 32, 32, 64)        │          18,496 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 32, 32, 64)        │               0 │ conv2d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_5 (Conv2D)             │ (None, 32, 32, 64)        │          36,928 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 16, 64)        │               0 │ conv2d_5[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_6 (Conv2D)             │ (None, 16, 16, 128)       │          73,856 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 16, 16, 128)       │               0 │ conv2d_6[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_7 (Conv2D)             │ (None, 16, 16, 128)       │         147,584 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d (UpSampling2D)  │ (None, 32, 32, 128)       │               0 │ conv2d_7[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 32, 32, 192)       │               0 │ up_sampling2d[0][0],       │
# │                               │                           │                 │ conv2d_5[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_8 (Conv2D)             │ (None, 32, 32, 64)        │         110,656 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_9 (Conv2D)             │ (None, 32, 32, 64)        │          36,928 │ conv2d_8[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_1               │ (None, 64, 64, 64)        │               0 │ conv2d_9[0][0]             │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 64, 64, 96)        │               0 │ up_sampling2d_1[0][0],     │
# │                               │                           │                 │ conv2d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_10 (Conv2D)            │ (None, 64, 64, 32)        │          27,680 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 64, 64, 32)        │           9,248 │ conv2d_10[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ up_sampling2d_2               │ (None, 128, 128, 32)      │               0 │ conv2d_11[0][0]            │
# │ (UpSampling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 128, 128, 48)      │               0 │ up_sampling2d_2[0][0],     │
# │                               │                           │                 │ conv2d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 128, 128, 16)      │           6,928 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 128, 128, 16)      │           2,320 │ conv2d_12[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 128, 128, 1)       │              17 │ conv2d_13[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 487,297 (1.86 MB)
#  Trainable params: 487,297 (1.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# --- CONFIGURATION DES ASSISTANTS PROFESSIONNELS ---
early_stopper = EarlyStopping(
    monitor='val_loss', 
    patience=10,         # On augmente la patience à 10 pour laisser le LR baisser
    verbose=1,
    restore_best_weights=True 
)

checkpointer = ModelCheckpoint(
    'meilleur_modele_unet.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# Nouveau : Le régulateur pour passer de 0.76 à 0.80+ d'IoU
lr_reducer = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    verbose=1,
    min_lr=1e-7
)

# --- LANCEMENT DE L'ENTRAÎNEMENT ---
history = model.fit(
    X_train, Y_train,
    validation_split=0.1, 
    batch_size=16,         # Bien pour tes 8Go de RAM
    epochs=100, 
    # On ajoute lr_reducer dans la liste des assistants
    callbacks=[early_stopper, checkpointer, lr_reducer] 
)
# Out:
# Epoch 1/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.6018 - iou_metric: 0.2856 - loss: 0.5426
# Epoch 1: val_loss improved from None to 0.39962, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 512s 787ms/step - accuracy: 0.6313 - iou_metric: 0.4001 - loss: 0.4860 - val_accuracy: 0.6781 - val_iou_metric: 0.5478 - val_loss: 0.3996 - learning_rate: 0.0010
# Epoch 2/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 0.6805 - iou_metric: 0.5583 - loss: 0.3925
# Epoch 2: val_loss improved from 0.39962 to 0.35819, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 512s 800ms/step - accuracy: 0.6916 - iou_metric: 0.5834 - loss: 0.3716 - val_accuracy: 0.6959 - val_iou_metric: 0.6075 - val_loss: 0.3582 - learning_rate: 0.0010
# Epoch 3/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - accuracy: 0.7056 - iou_metric: 0.6193 - loss: 0.3402
# Epoch 3: val_loss improved from 0.35819 to 0.30598, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 494s 772ms/step - accuracy: 0.7087 - iou_metric: 0.6328 - loss: 0.3313 - val_accuracy: 0.7196 - val_iou_metric: 0.6585 - val_loss: 0.3060 - learning_rate: 0.0010
# Epoch 4/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.7186 - iou_metric: 0.6602 - loss: 0.3056
# Epoch 4: val_loss improved from 0.30598 to 0.29586, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 549s 859ms/step - accuracy: 0.7183 - iou_metric: 0.6601 - loss: 0.3071 - val_accuracy: 0.7228 - val_iou_metric: 0.6796 - val_loss: 0.2959 - learning_rate: 0.0010
# Epoch 5/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - accuracy: 0.7234 - iou_metric: 0.6775 - loss: 0.2940
# Epoch 5: val_loss improved from 0.29586 to 0.28719, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 476s 743ms/step - accuracy: 0.7241 - iou_metric: 0.6790 - loss: 0.2929 - val_accuracy: 0.7255 - val_iou_metric: 0.6882 - val_loss: 0.2872 - learning_rate: 0.0010
# Epoch 6/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - accuracy: 0.7260 - iou_metric: 0.6859 - loss: 0.2901
# Epoch 6: val_loss did not improve from 0.28719
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 474s 741ms/step - accuracy: 0.7269 - iou_metric: 0.6874 - loss: 0.2858 - val_accuracy: 0.7154 - val_iou_metric: 0.6846 - val_loss: 0.3077 - learning_rate: 0.0010
# Epoch 7/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.7293 - iou_metric: 0.6986 - loss: 0.2758
# Epoch 7: val_loss did not improve from 0.28719
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 480s 750ms/step - accuracy: 0.7311 - iou_metric: 0.7004 - loss: 0.2750 - val_accuracy: 0.7193 - val_iou_metric: 0.6903 - val_loss: 0.3073 - learning_rate: 0.0010
# Epoch 8/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - accuracy: 0.7316 - iou_metric: 0.7053 - loss: 0.2721
# Epoch 8: val_loss improved from 0.28719 to 0.27189, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 491s 766ms/step - accuracy: 0.7335 - iou_metric: 0.7076 - loss: 0.2675 - val_accuracy: 0.7331 - val_iou_metric: 0.7017 - val_loss: 0.2719 - learning_rate: 0.0010
# Epoch 9/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 721ms/step - accuracy: 0.7342 - iou_metric: 0.7085 - loss: 0.2691
# Epoch 9: val_loss did not improve from 0.27189
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 475s 742ms/step - accuracy: 0.7347 - iou_metric: 0.7102 - loss: 0.2644 - val_accuracy: 0.7339 - val_iou_metric: 0.7088 - val_loss: 0.2744 - learning_rate: 0.0010
# Epoch 10/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - accuracy: 0.7347 - iou_metric: 0.7173 - loss: 0.2629
# Epoch 10: val_loss improved from 0.27189 to 0.26501, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 484s 757ms/step - accuracy: 0.7364 - iou_metric: 0.7167 - loss: 0.2600 - val_accuracy: 0.7338 - val_iou_metric: 0.7116 - val_loss: 0.2650 - learning_rate: 0.0010
# Epoch 11/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.7370 - iou_metric: 0.7231 - loss: 0.2560
# Epoch 11: val_loss improved from 0.26501 to 0.26332, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 473s 739ms/step - accuracy: 0.7384 - iou_metric: 0.7227 - loss: 0.2532 - val_accuracy: 0.7341 - val_iou_metric: 0.7230 - val_loss: 0.2633 - learning_rate: 0.0010
# Epoch 12/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.7366 - iou_metric: 0.7232 - loss: 0.2535
# Epoch 12: val_loss improved from 0.26332 to 0.26119, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 499s 733ms/step - accuracy: 0.7395 - iou_metric: 0.7265 - loss: 0.2502 - val_accuracy: 0.7345 - val_iou_metric: 0.7124 - val_loss: 0.2612 - learning_rate: 0.0010
# Epoch 13/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.7382 - iou_metric: 0.7315 - loss: 0.2494
# Epoch 13: val_loss improved from 0.26119 to 0.25768, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 517s 756ms/step - accuracy: 0.7414 - iou_metric: 0.7330 - loss: 0.2447 - val_accuracy: 0.7395 - val_iou_metric: 0.7299 - val_loss: 0.2577 - learning_rate: 0.0010
# Epoch 14/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - accuracy: 0.7419 - iou_metric: 0.7321 - loss: 0.2438
# Epoch 14: val_loss did not improve from 0.25768
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 498s 779ms/step - accuracy: 0.7415 - iou_metric: 0.7327 - loss: 0.2449 - val_accuracy: 0.7347 - val_iou_metric: 0.7175 - val_loss: 0.2586 - learning_rate: 0.0010
# Epoch 15/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - accuracy: 0.7421 - iou_metric: 0.7281 - loss: 0.2441
# Epoch 15: val_loss improved from 0.25768 to 0.24619, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 485s 758ms/step - accuracy: 0.7428 - iou_metric: 0.7368 - loss: 0.2398 - val_accuracy: 0.7411 - val_iou_metric: 0.7374 - val_loss: 0.2462 - learning_rate: 0.0010
# Epoch 16/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 715ms/step - accuracy: 0.7466 - iou_metric: 0.7468 - loss: 0.2307
# Epoch 16: val_loss improved from 0.24619 to 0.24578, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 489s 737ms/step - accuracy: 0.7437 - iou_metric: 0.7404 - loss: 0.2366 - val_accuracy: 0.7430 - val_iou_metric: 0.7404 - val_loss: 0.2458 - learning_rate: 0.0010
# Epoch 17/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.7452 - iou_metric: 0.7477 - loss: 0.2303
# Epoch 17: val_loss did not improve from 0.24578
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 511s 751ms/step - accuracy: 0.7448 - iou_metric: 0.7438 - loss: 0.2334 - val_accuracy: 0.7404 - val_iou_metric: 0.7374 - val_loss: 0.2489 - learning_rate: 0.0010
# Epoch 18/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.7466 - iou_metric: 0.7486 - loss: 0.2280
# Epoch 18: val_loss did not improve from 0.24578
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 502s 751ms/step - accuracy: 0.7452 - iou_metric: 0.7445 - loss: 0.2316 - val_accuracy: 0.7409 - val_iou_metric: 0.7386 - val_loss: 0.2596 - learning_rate: 0.0010
# Epoch 19/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.7438 - iou_metric: 0.7474 - loss: 0.2307
# Epoch 19: val_loss improved from 0.24578 to 0.24559, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 491s 733ms/step - accuracy: 0.7463 - iou_metric: 0.7488 - loss: 0.2282 - val_accuracy: 0.7423 - val_iou_metric: 0.7233 - val_loss: 0.2456 - learning_rate: 0.0010
# Epoch 20/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 721ms/step - accuracy: 0.7473 - iou_metric: 0.7560 - loss: 0.2234
# Epoch 20: val_loss did not improve from 0.24559
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 475s 742ms/step - accuracy: 0.7467 - iou_metric: 0.7514 - loss: 0.2263 - val_accuracy: 0.7415 - val_iou_metric: 0.7357 - val_loss: 0.2475 - learning_rate: 0.0010
# Epoch 21/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.7477 - iou_metric: 0.7517 - loss: 0.2256
# Epoch 21: val_loss improved from 0.24559 to 0.23764, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 467s 730ms/step - accuracy: 0.7469 - iou_metric: 0.7512 - loss: 0.2250 - val_accuracy: 0.7447 - val_iou_metric: 0.7480 - val_loss: 0.2376 - learning_rate: 0.0010
# Epoch 22/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.7513 - iou_metric: 0.7572 - loss: 0.2189
# Epoch 22: val_loss did not improve from 0.23764
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 473s 739ms/step - accuracy: 0.7485 - iou_metric: 0.7558 - loss: 0.2211 - val_accuracy: 0.7392 - val_iou_metric: 0.7406 - val_loss: 0.2557 - learning_rate: 0.0010
# Epoch 23/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.7489 - iou_metric: 0.7636 - loss: 0.2156
# Epoch 23: val_loss did not improve from 0.23764
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 479s 748ms/step - accuracy: 0.7496 - iou_metric: 0.7609 - loss: 0.2170 - val_accuracy: 0.7261 - val_iou_metric: 0.7106 - val_loss: 0.2792 - learning_rate: 0.0010
# Epoch 24/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 721ms/step - accuracy: 0.7501 - iou_metric: 0.7612 - loss: 0.2166
# Epoch 24: val_loss did not improve from 0.23764
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 475s 742ms/step - accuracy: 0.7495 - iou_metric: 0.7597 - loss: 0.2170 - val_accuracy: 0.7425 - val_iou_metric: 0.7449 - val_loss: 0.2390 - learning_rate: 0.0010
# Epoch 25/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.7532 - iou_metric: 0.7775 - loss: 0.2023
# Epoch 25: val_loss improved from 0.23764 to 0.22463, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 477s 745ms/step - accuracy: 0.7558 - iou_metric: 0.7820 - loss: 0.1970 - val_accuracy: 0.7493 - val_iou_metric: 0.7631 - val_loss: 0.2246 - learning_rate: 2.0000e-04
# Epoch 26/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 721ms/step - accuracy: 0.7592 - iou_metric: 0.7895 - loss: 0.1897
# Epoch 26: val_loss did not improve from 0.22463
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 475s 742ms/step - accuracy: 0.7572 - iou_metric: 0.7871 - loss: 0.1915 - val_accuracy: 0.7488 - val_iou_metric: 0.7648 - val_loss: 0.2259 - learning_rate: 2.0000e-04
# Epoch 27/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 715ms/step - accuracy: 0.7605 - iou_metric: 0.7935 - loss: 0.1849
# Epoch 27: val_loss did not improve from 0.22463
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 498s 736ms/step - accuracy: 0.7578 - iou_metric: 0.7889 - loss: 0.1896 - val_accuracy: 0.7506 - val_iou_metric: 0.7651 - val_loss: 0.2262 - learning_rate: 2.0000e-04
# Epoch 28/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.7586 - iou_metric: 0.7879 - loss: 0.1868
# Epoch 28: val_loss did not improve from 0.22463
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 479s 749ms/step - accuracy: 0.7584 - iou_metric: 0.7901 - loss: 0.1876 - val_accuracy: 0.7507 - val_iou_metric: 0.7675 - val_loss: 0.2253 - learning_rate: 2.0000e-04
# Epoch 29/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.7575 - iou_metric: 0.7924 - loss: 0.1857
# Epoch 29: val_loss improved from 0.22463 to 0.22463, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 477s 745ms/step - accuracy: 0.7598 - iou_metric: 0.7958 - loss: 0.1828 - val_accuracy: 0.7510 - val_iou_metric: 0.7675 - val_loss: 0.2246 - learning_rate: 4.0000e-05
# Epoch 30/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.7590 - iou_metric: 0.7963 - loss: 0.1825
# Epoch 30: val_loss improved from 0.22463 to 0.22451, saving model to meilleur_modele_unet.keras
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 471s 735ms/step - accuracy: 0.7600 - iou_metric: 0.7957 - loss: 0.1819 - val_accuracy: 0.7514 - val_iou_metric: 0.7692 - val_loss: 0.2245 - learning_rate: 4.0000e-05
# Epoch 31/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.7566 - iou_metric: 0.7932 - loss: 0.1854
# Epoch 31: val_loss did not improve from 0.22451
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 476s 744ms/step - accuracy: 0.7600 - iou_metric: 0.7968 - loss: 0.1817 - val_accuracy: 0.7509 - val_iou_metric: 0.7692 - val_loss: 0.2260 - learning_rate: 4.0000e-05
# Epoch 32/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.7603 - iou_metric: 0.7977 - loss: 0.1800
# Epoch 32: val_loss did not improve from 0.22451
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 493s 730ms/step - accuracy: 0.7602 - iou_metric: 0.7970 - loss: 0.1811 - val_accuracy: 0.7518 - val_iou_metric: 0.7695 - val_loss: 0.2251 - learning_rate: 4.0000e-05
# Epoch 33/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.7599 - iou_metric: 0.7981 - loss: 0.1808
# Epoch 33: val_loss did not improve from 0.22451
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 508s 739ms/step - accuracy: 0.7603 - iou_metric: 0.7975 - loss: 0.1806 - val_accuracy: 0.7518 - val_iou_metric: 0.7707 - val_loss: 0.2255 - learning_rate: 4.0000e-05
# Epoch 34/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.7622 - iou_metric: 0.7977 - loss: 0.1781
# Epoch 34: val_loss did not improve from 0.22451
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 503s 741ms/step - accuracy: 0.7606 - iou_metric: 0.7990 - loss: 0.1795 - val_accuracy: 0.7513 - val_iou_metric: 0.7704 - val_loss: 0.2259 - learning_rate: 8.0000e-06
# Epoch 35/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - accuracy: 0.7629 - iou_metric: 0.8021 - loss: 0.1757
# Epoch 35: val_loss did not improve from 0.22451
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 506s 747ms/step - accuracy: 0.7607 - iou_metric: 0.7995 - loss: 0.1792 - val_accuracy: 0.7516 - val_iou_metric: 0.7707 - val_loss: 0.2248 - learning_rate: 8.0000e-06
# Epoch 36/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.7621 - iou_metric: 0.8015 - loss: 0.1792
# Epoch 36: val_loss did not improve from 0.22451
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 470s 734ms/step - accuracy: 0.7608 - iou_metric: 0.7999 - loss: 0.1793 - val_accuracy: 0.7513 - val_iou_metric: 0.7707 - val_loss: 0.2257 - learning_rate: 8.0000e-06
# Epoch 37/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.7612 - iou_metric: 0.8018 - loss: 0.1777
# Epoch 37: val_loss did not improve from 0.22451
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 514s 753ms/step - accuracy: 0.7607 - iou_metric: 0.7997 - loss: 0.1792 - val_accuracy: 0.7515 - val_iou_metric: 0.7707 - val_loss: 0.2254 - learning_rate: 1.6000e-06
# Epoch 38/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 713ms/step - accuracy: 0.7607 - iou_metric: 0.8009 - loss: 0.1797
# Epoch 38: val_loss did not improve from 0.22451
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 471s 735ms/step - accuracy: 0.7607 - iou_metric: 0.7999 - loss: 0.1790 - val_accuracy: 0.7516 - val_iou_metric: 0.7708 - val_loss: 0.2253 - learning_rate: 1.6000e-06
# Epoch 39/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.7639 - iou_metric: 0.8016 - loss: 0.1779
# Epoch 39: val_loss did not improve from 0.22451
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 521s 766ms/step - accuracy: 0.7607 - iou_metric: 0.7994 - loss: 0.1792 - val_accuracy: 0.7516 - val_iou_metric: 0.7709 - val_loss: 0.2254 - learning_rate: 1.6000e-06
# Epoch 40/100
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7599 - iou_metric: 0.7982 - loss: 0.1801
# Epoch 40: val_loss did not improve from 0.22451
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 738s 1s/step - accuracy: 0.7608 - iou_metric: 0.8001 - loss: 0.1790 - val_accuracy: 0.7516 - val_iou_metric: 0.7708 - val_loss: 0.2254 - learning_rate: 3.2000e-07
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.

# %%
#  On récupère les données brutes de l'entraînement
# 'history.history' est un dictionnaire qui contient toutes les notes tour par tour.
loss = history.history['loss']            # Erreur sur les données d'entraînement
val_loss = history.history['val_loss']    # Erreur sur les données de validation (Test)
iou = history.history['iou_metric']       # Score IoU sur l'entraînement
val_iou = history.history['val_iou_metric'] # Score IoU sur la validation

# On crée l'axe des X (le nombre de tours effectués)
epochs_range = range(len(loss))

#  On prépare le dessin (Une figure large avec 2 graphiques)
plt.figure(figsize=(14, 5))

# --- GRAPHIQUE DE GAUCHE : L'ERREUR (LOSS) ---
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Entraînement (Train Loss)')
plt.plot(epochs_range, val_loss, label='Validation (Val Loss)')
plt.title('Courbe d\'Erreur (Plus bas = Mieux)')
plt.legend(loc='upper right') # Affiche la légende
plt.grid(True) # Ajoute une grille pour faciliter la lecture

# --- GRAPHIQUE DE DROITE : LA PERFORMANCE (IoU) ---
plt.subplot(1, 2, 2)
plt.plot(epochs_range, iou, label='Entraînement (Train IoU)')
plt.plot(epochs_range, val_iou, label='Validation (Val IoU)')
plt.title('Score IoU (Plus haut = Mieux)')
plt.legend(loc='lower right')
plt.grid(True)

# 3. Affichage final
plt.show()

# %%
#  GÉNÉRATION DES PRÉDICTIONS
# On demande au modèle de prédire les masques pour TOUTES les images de test.
print("Génération des prédictions en cours...")
preds_test = model.predict(X_test, verbose=1)

# Le modèle sort des probabilités, On tranche : Si > 0.5 c'est blanc (1), sinon c'est noir (0).
preds_test_t = (preds_test > 0.5).astype(np.uint8)


#  ÉVALUATION CHIFFRÉE (Les Notes)

# On compare mathématiquement les prédictions avec les vrais masques (Y_test)
# model.evaluate retourne une liste : [Loss, Accuracy, IoU_Metric]
score = model.evaluate(X_test, Y_test, verbose=0)

print("--- RÉSULTATS DU TEST ---")
print(f"Perte (Loss)        : {score[0]:.4f}") # Doit être bas
print(f"Précision (Accuracy): {score[1]:.4f}") # Souvent trompeur
print(f"Score IoU (Métrique): {score[2]:.4f}") # LA vraie note importante !


# 3. VISUALISATION (La Preuve par l'Image)
# On va piocher 3 images au hasard dans le test pour voir le résultat.

for i in range(3):
    # On choisit un index au hasard
    idx = random.randint(0, len(X_test) - 1)
    
    plt.figure(figsize=(15, 5))
    
    # --- IMAGE ORIGINALE ---
    plt.subplot(1, 3, 1)
    # X_test est en RGB (couleur)
    plt.imshow(X_test[idx]) 
    plt.title("Image Originale")
    plt.axis('off')
    
    # --- VRAI MASQUE (La Correction) ---
    plt.subplot(1, 3, 2)
    # .squeeze() sert à enlever la dimension "1" inutile (128, 128, 1) -> (128, 128)
    plt.imshow(Y_test[idx].squeeze(), cmap='gray')
    plt.title("Vrai Masque (Ground Truth)")
    plt.axis('off')
    
    # --- PRÉDICTION (Ce que l'IA a vu) ---
    plt.subplot(1, 3, 3)
    plt.imshow(preds_test_t[idx].squeeze(), cmap='gray')
    plt.title(f"Prédiction IA")
    plt.axis('off')
    
    plt.show()
# Out:
# Génération des prédictions en cours...
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 54s 591ms/step
# --- RÉSULTATS DU TEST ---
# Perte (Loss)        : 0.2180
# Précision (Accuracy): 0.7479
# Score IoU (Métrique): 0.7663
